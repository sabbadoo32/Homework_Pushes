# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
heroes_of_pymoli = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
hop_spender_pd = pd.read_csv(heroes_of_pymoli)

hop_idx = pd.read_csv(heroes_of_pymoli)

import numpy as np

# %%
# Import the books.csv file as a DataFrame
hop_df = pd.read_csv(heroes_of_pymoli, encoding="utf-8")
hop_df.dropna() 
hop_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
hop_df.dtypes
# Out:
# Purchase ID      int64
# SN              object
# Age              int64
# Gender          object
# Item ID          int64
# Item Name       object
# Price          float64
# dtype: object

# %%
hop_df.rename(columns={'Item Name':'Purchases'}, inplace=True)
hop_df
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %%
hop_df['Price'] = hop_df['Price'].astype(float)

# %%
hop_df['SN'] = hop_df['SN'].astype(str)

# %%
hop_df['Price'].sum()
# Out:
# 2379.77

# %%
print(hop_df['Purchases'].count())
# Out:
# 780

# %%
average_price = hop_df['Price'].sum() / hop_df['Purchases'].count()
print(average_price)
# Out:
# 3.0509871794871795

# %%
hop_male_purchases_df = hop_df.loc[ \
    hop_df["Gender"] == "Male"]
hop_male_purchases_df
# Out:
#      Purchase ID              SN  Age Gender  Item ID  \
# 0              0         Lisim78   20   Male      108
# 1              1     Lisovynya38   40   Male      143
# 2              2      Ithergue48   24   Male       92
# 3              3   Chamassasya86   24   Male      100
# 4              4       Iskosia90   23   Male      131
# 5              5         Yalae81   22   Male       81
# 6              6       Itheria73   36   Male      169
# 7              7     Iskjaskst81   20   Male      162
# 8              8       Undjask33   22   Male       21
# 10            10       Inguron55   23   Male       95
# 11            11    Haisrisuir60   23   Male      162
# 12            12    Saelaephos52   21   Male      116
# 13            13     Assjaskan73   22   Male        4
# 14            14     Saesrideu94   35   Male      165
# 16            16       Lisirra25   20   Male       40
# 17            17       Zontibe81   21   Male      161
# ...

# %%
hop_male_purchases_df['Purchases'].count()
# Out:
# 652

# %%
hop_male_purchases_df['Price'].sum()
# Out:
# 1967.64

# %%
male_average_price = hop_male_purchases_df['Price'].sum() / hop_male_purchases_df['Purchases'].count()
print(average_price)
# Out:
# 3.0509871794871795

# %%
hop_female_purchases_df = hop_df.loc[ \
    hop_df["Gender"] == "Female"]
hop_female_purchases_df
# Out:
#      Purchase ID               SN  Age  Gender  Item ID  \
# 15            15        Lisassa64   21  Female       98
# 18            18        Reunasu60   22  Female       82
# 38            38         Reulae52   10  Female      116
# 41            41        Assosia88   20  Female        7
# 55            55        Phaelap26   25  Female       84
# 66            66     Chanastsda67   21  Female        6
# 71            71           Hari50   20  Female       29
# 72            72        Marilsa69   25  Female      178
# 76            76     Mindadaran26   13  Female       88
# 81            81         Heudai45    8  Female      174
# 84            84       Jiskjask60   21  Female       34
# 85            85       Umolrian85   32  Female       33
# 92            92     Chadistaya75   21  Female       39
# 112          112     Iskichinya81   21  Female        7
# 113          113         Phyali88   15  Female      140
# 117          117    Frichaststa61   21  Female      117
# ...

# %%
hop_female_purchases_df['Purchases'].count()
# Out:
# 113

# %%
hop_female_purchases_df['Price'].sum()
# Out:
# 361.94

# %%
female_average_price = hop_female_purchases_df['Price'].sum() / hop_female_purchases_df['Purchases'].count()
print(average_price)
# Out:
# 3.0509871794871795

# %%
hop_other_df = hop_df.loc[ \
    hop_df["Gender"] == "Other / Non-Disclosed"]
hop_other_df
# Out:
#      Purchase ID            SN  Age                 Gender  Item ID  \
# 9              9   Chanosian48   35  Other / Non-Disclosed      136
# 22            22  Siarithria38   38  Other / Non-Disclosed       24
# 82            82    Haerithp41   16  Other / Non-Disclosed      160
# 111          111      Sundim98   21  Other / Non-Disclosed       41
# 228          228   Jiskirran77   20  Other / Non-Disclosed       80
# 237          237     Idairin51   20  Other / Non-Disclosed       16
# 242          242     Eodaisu60   16  Other / Non-Disclosed       39
# 291          291     Idairin51   20  Other / Non-Disclosed       35
# 350          350     Rairith81   15  Other / Non-Disclosed       34
# 401          401      Lirtim36   15  Other / Non-Disclosed       46
# 484          484   Chanosian48   35  Other / Non-Disclosed       39
# 549          549    Maluncil97   25  Other / Non-Disclosed      146
# 629          629    Maluncil97   25  Other / Non-Disclosed      107
# ...

# %%
hop_other_df['Purchases'].count()
# Out:
# 15

# %%
hop_other_df['Price'].sum()
# Out:
# 50.19

# %%
other_average_price = hop_other_df['Price'].sum() / hop_other_df['Purchases'].count()
print(average_price)
# Out:
# 3.0509871794871795

# %%
hop_SN_count_df = hop_df["SN"].count()
hop_SN_count_df
# Out:
# 780

# %%
# Using GroupBy in order to separate the data into fields according to "state" values
hop_grouped_df = hop_df.groupby(['Age'])


# The object returned is a "GroupBy" object and cannot be viewed normally...
print(hop_grouped_df)

# In order to be visualized, a data function must be used...
hop_grouped_df.count().head(10)
# Out:
# ...
#      Purchase ID  SN  Gender  Item ID  Purchases  Price
# Age
# 7              9   9       9        9          9      9
# 8              8   8       8        8          8      8
# 9              6   6       6        6          6      6
# 10             9   9       9        9          9      9
# 11             7   7       7        7          7      7
# 12             6   6       6        6          6      6
# 13             4   4       4        4          4      4
# 14             2   2       2        2          2      2
# 15            35  35      35       35         35     35
# 16            30  30      30       30         30     30

# %%
hop_pd = pd.read_csv(heroes_of_pymoli)
hop_pd.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
hop_pd.rename(columns={'Item Name':'Purchases'}, inplace=True)
hop_pd.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Purchases  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
hop_type_pd = hop_pd[["SN", "Gender", "Age",
                      "Purchases", "Price"]]
hop_type_pd.head()
# Out:
#               SN Gender  Age                                  Purchases  Price
# 0        Lisim78   Male   20  Extraction, Quickblade Of Trembling Hands   3.53
# 1    Lisovynya38   Male   40                          Frenzied Scimitar   1.56
# 2     Ithergue48   Male   24                               Final Critic   4.88
# 3  Chamassasya86   Male   24                                Blindscythe   3.27
# 4      Iskosia90   Male   23                                       Fury   1.44

# %%
# Create the GroupBy object based on the "Type 1" column
hop_group_pd = hop_type.groupby(["Age"])
hop_group_pd.head()
# Out:
#                  SN                 Gender  Age  \
# 0           Lisim78                   Male   20
# 1       Lisovynya38                   Male   40
# 2        Ithergue48                   Male   24
# 3     Chamassasya86                   Male   24
# 4         Iskosia90                   Male   23
# 5           Yalae81                   Male   22
# 6         Itheria73                   Male   36
# 7       Iskjaskst81                   Male   20
# 8         Undjask33                   Male   22
# 9       Chanosian48  Other / Non-Disclosed   35
# 10        Inguron55                   Male   23
# 11     Haisrisuir60                   Male   23
# 12     Saelaephos52                   Male   21
# 13      Assjaskan73                   Male   22
# 14      Saesrideu94                   Male   35
# 15        Lisassa64                 Female   21
# 16        Lisirra25                   Male   20
# 17        Zontibe81                   Male   21
# ...
